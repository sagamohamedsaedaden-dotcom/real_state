# %%
import warnings

from warnings import filterwarnings;
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns 
plt.style.use('ggplot')
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('world_real_estate_data(147k).csv')

# %%
df_UAE=df[df['country'] == 'UAE']

# %%
df_UAE = df_UAE.rename(columns={
    'apartment_bedrooms': 'beds',
    'apartment_bathrooms': 'baths',
    'apartment_total_area': 'area_sqm',
    'price_in_USD': 'price_USD',
    'location': 'address',
    'building_construction_year': 'year_of_completion'
})

# %%
df_UAE['price_USD']
# Out:
# 14         97930.0
# 130206    244755.0
# 130207    157906.0
# 130223    233000.0
# 130224    250000.0
#             ...
# 147479    136948.0
# 147481    171233.0
# 147482    131000.0
# 147483    188992.0
# 147484    121500.0
# Name: price_USD, Length: 2675, dtype: float64

# %%
df_UAE.shape
# Out:
# (2675, 14)

# %%
df_UAE.isnull().sum()
# Out:
# title                       0
# country                     0
# address                     0
# year_of_completion       1314
# building_total_floors    1643
# apartment_floor          2078
# apartment_rooms           462
# beds                     1135
# baths                    1499
# area_sqm                  104
# apartment_living_area    2622
# price_USD                   1
# image                       0
# url                         0
# dtype: int64

# %%
df_UAE.drop_duplicates(subset=['address','area_sqm','price_USD'],inplace=True)

# %%
df_UAE.shape
# Out:
# (2590, 14)

# %%
df_UAE['year_of_completion']=pd.to_datetime(df_UAE['year_of_completion'])

# %%
df_UAE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2590 entries, 14 to 147483
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  2590 non-null   object
#  1   country                2590 non-null   object
#  2   address                2590 non-null   object
#  3   year_of_completion     1301 non-null   datetime64[ns]
#  4   building_total_floors  1015 non-null   float64
#  5   apartment_floor        589 non-null    float64
#  6   apartment_rooms        2145 non-null   float64
#  7   beds                   1498 non-null   float64
#  8   baths                  1136 non-null   float64
#  9   area_sqm               2488 non-null   object
#  10  apartment_living_area  53 non-null     object
#  11  price_USD              2589 non-null   float64
#  12  image                  2590 non-null   object
#  13  url                    2590 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 303.5+ KB

# %%
df_UAE.describe()
# Out:
#                   year_of_completion  building_total_floors  apartment_floor  \
# count                           1301            1015.000000       589.000000
# mean   1970-01-01 00:00:00.000002023              27.360591        16.624788
# min    1970-01-01 00:00:00.000002009               1.000000         1.000000
# 25%    1970-01-01 00:00:00.000002022              10.000000         5.000000
# 50%    1970-01-01 00:00:00.000002024              21.000000        11.000000
# 75%    1970-01-01 00:00:00.000002025              45.000000        21.000000
# max    1970-01-01 00:00:00.000002028             124.000000       202.000000
# std                              NaN              20.956234        17.209102
#
#        apartment_rooms         beds        baths     price_USD
# count      2145.000000  1498.000000  1136.000000  2.589000e+03
# mean          2.689044     1.958611     2.111796  1.289098e+06
# min          -1.000000     1.000000     1.000000  6.050000e+04
# 25%           2.000000     1.000000     1.000000  2.952530e+05
# 50%           3.000000     2.000000     2.000000  5.130000e+05
# 75%           3.000000     2.000000     3.000000  9.308320e+05
# max          10.000000     9.000000     9.000000  2.913102e+07
# std           1.396222     1.103657     1.323725  2.560386e+06

# %%
# df_UAE['year'] = pd.to_datetime(df_UAE['year_of_completion'], errors='coerce').dt.year
df_UAE['year'] = df_UAE['year_of_completion'].dt.year

# %%
df_UAE
# Out:
#                                                  title country  \
# 14           1 room studio apartment 38 m² in UAE, UAE     UAE
# 130206            1 room apartment 90 m² in Dubai, UAE     UAE
# 130207        Apartment 1 bathroom 35 m² in Dubai, UAE     UAE
# 130223            1 room apartment 78 m² in Dubai, UAE     UAE
# 130224            2 room apartment 70 m² in Dubai, UAE     UAE
# ...                                                ...     ...
# 147477            1 room apartment 35 m² in Dubai, UAE     UAE
# 147478            1 room apartment 89 m² in Ajman, UAE     UAE
# 147479            1 room apartment 59 m² in Dubai, UAE     UAE
# 147481  1 room apartment 42 m² in Sharjah Emirate, UAE     UAE
# 147483           1 room apartment 700 m² in Dubai, UAE     UAE
#
#                           address            year_of_completion  \
# 14                            UAE 1970-01-01 00:00:00.000002024
# 130206                 Dubai, UAE                           NaT
# 130207                 Dubai, UAE                           NaT
# 130223                 Dubai, UAE                           NaT
# 130224                 Dubai, UAE 1970-01-01 00:00:00.000002022
# ...                           ...                           ...
# 147477                 Dubai, UAE 1970-01-01 00:00:00.000002022
# 147478  Ajman Emirate, Ajman, UAE 1970-01-01 00:00:00.000002023
# 147479                 Dubai, UAE                           NaT
# 147481       Sharjah Emirate, UAE 1970-01-01 00:00:00.000002025
# 147483                 Dubai, UAE                           NaT
#
#         building_total_floors  apartment_floor  apartment_rooms  beds  baths  \
# 14                        6.0              NaN              1.0   1.0    1.0
# 130206                    NaN              NaN              NaN   1.0    1.0
# 130207                    NaN              NaN              NaN   NaN    1.0
# 130223                    NaN              NaN              NaN   1.0    2.0
# 130224                   30.0              3.0              2.0   2.0    1.0
# ...                       ...              ...              ...   ...    ...
# 147477                    NaN              NaN              1.0   NaN    NaN
# 147478                   40.0              2.0              2.0   1.0    2.0
# 147479                   40.0             26.0              2.0   1.0    1.0
# 147481                    6.0              NaN              2.0   1.0    1.0
# 147483                    NaN              NaN              1.0   NaN    2.0
#
#        area_sqm apartment_living_area  price_USD  \
# 14        38 m²                 38 m²    97930.0
# 130206    90 m²                   NaN   244755.0
# 130207    35 m²                   NaN   157906.0
# 130223    78 m²                   NaN   233000.0
# 130224    70 m²                   NaN   250000.0
# ...         ...                   ...        ...
# 147477    35 m²                   NaN   168110.0
# 147478    89 m²                   NaN   113135.0
# 147479    59 m²                   NaN   136948.0
# 147481    42 m²                   NaN   171233.0
# 147483   700 m²                   NaN   188992.0
#
#                                                     image  \
# 14      https://realting.com/uploads/bigSlider/6e3/0b5...
# 130206  https://realting.com/uploads/bigSlider/58e/bb2...
# 130207  https://realting.com/uploads/bigSlider/d5d/b56...
# 130223  https://realting.com/uploads/bigSlider/a99/2d7...
# 130224  https://realting.com/uploads/bigSlider/54a/b72...
# ...                                                   ...
# 147477  https://realting.com/uploads/bigSlider/666/963...
# 147478  https://realting.com/uploads/bigSlider/294/cdc...
# 147479  https://realting.com/uploads/bigSlider/666/6de...
# 147481  https://realting.com/uploads/bigSlider/e31/f2d...
# 147483  https://realting.com/uploads/bigSlider/c61/9cb...
#
#                                                       url    year
# 14      https://realting.com/property-for-sale/united-...  1970.0
# 130206  https://realting.com/property-for-sale/united-...     NaN
# 130207  https://realting.com/property-for-sale/united-...     NaN
# 130223  https://realting.com/property-for-sale/united-...     NaN
# 130224  https://realting.com/property-for-sale/united-...  1970.0
# ...                                                   ...     ...
# 147477  https://realting.com/property-for-sale/united-...  1970.0
# 147478  https://realting.com/property-for-sale/united-...  1970.0
# 147479  https://realting.com/property-for-sale/united-...     NaN
# 147481  https://realting.com/property-for-sale/united-...  1970.0
# 147483  https://realting.com/property-for-sale/united-...     NaN
#
# [2590 rows x 15 columns]

# %%
numeric_df=df_UAE.select_dtypes(include=['float','int'])
corr_matrix=numeric_df.corr()

# %%
fig=px.imshow(corr_matrix,text_auto=True,aspect=True, title='Correlation Matrix'
,color_continuous_scale='RdBu_r')
plt.figure(figsize=(10, 10))
fig.show()

# %%
df_UAE=df_UAE.fillna(0)

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_UAE['price_USD'], bins=100, color='salmon', edgecolor='black',kde=True)
plt.title('UAE Property Prices Distribution (Log Scale)', fontsize=16)
plt.xlabel('Price in USD')
plt.ylabel('Frequency')


#Converts numeric x-axis labels to human-readable money format
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.0f}M' 
                                            if x >= 1e6 else (f'${x/1e3:.0f}K' if x >= 1e3 else '$100K')))

plt.tight_layout()
plt.show()

# %%
UAE_Real_Estate=pd.read_csv('bayut_selling_properties.csv')

# %%
UAE_Real_Estate.columns
# Out:
# Index(['price', 'price_category', 'type', 'beds', 'baths', 'address',
#        'furnishing', 'completion_status', 'post_date', 'average_rent',
#        'building_name', 'year_of_completion', 'total_parking_spaces',
#        'total_floors', 'total_building_area_sqft', 'elevators', 'area_name',
#        'city', 'country', 'Latitude', 'Longitude', 'purpose'],
#       dtype='object')

# %%
UAE_Real_Estate.describe()
# Out:
#               price          beds         baths  average_rent  \
# count  4.138100e+04  41381.000000  41381.000000  4.138100e+04
# mean   3.788624e+06      2.190957      3.007540  9.292880e+04
# std    8.482870e+06      1.567855      1.785553  2.503703e+05
# min    0.000000e+00      0.000000      0.000000  0.000000e+00
# 25%    1.100000e+06      1.000000      2.000000  0.000000e+00
# 50%    2.000000e+06      2.000000      3.000000  0.000000e+00
# 75%    3.600000e+06      3.000000      4.000000  1.243790e+05
# max    4.825000e+08     11.000000     11.000000  2.807952e+07
#
#        year_of_completion  total_parking_spaces  total_floors  \
# count        41381.000000          41381.000000  41381.000000
# mean           681.112491            172.559073     13.212126
# std            953.886883            353.899074     20.298365
# min              0.000000              0.000000      0.000000
# 25%              0.000000              0.000000      0.000000
# 50%              0.000000              0.000000      0.000000
# 75%           2012.000000            198.000000     22.000000
# max           2024.000000           2929.000000     89.000000
#
#        total_building_area_sqft     elevators      Latitude     Longitude
# count              41381.000000  41381.000000  41363.000000  41363.000000
# mean                 142.931273      2.304463     25.037851     55.158407
# std                  248.719849      4.440953      0.437348      0.513871
# min                    0.000000      0.000000     15.175847     43.351928
# 25%                    0.000000      0.000000     25.026710     55.135252
# 50%                    0.000000      0.000000     25.078641     55.245999
# 75%                  211.000000      4.000000     25.189427     55.307913
# max                  997.000000     42.000000     25.797689     56.361294

# %%
UAE_Real_Estate.shape
# Out:
# (41381, 22)

# %%
UAE_Real_Estate.drop_duplicates(subset=['address', 'price'], inplace=True)

# %%
UAE_Real_Estate.shape
# Out:
# (31235, 22)

# %%
# Remove all rows containing zeros in the specified columns
UAE_RealState=UAE_Real_Estate[(UAE_Real_Estate[['baths','total_floors',
'total_building_area_sqft']]!=0).all(axis=1)] #all(axis=1) -> every condition in this row is True
UAE_RealState.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13979 entries, 2 to 41380
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   price                     13979 non-null  int64
#  1   price_category            13979 non-null  object
#  2   type                      13979 non-null  object
#  3   beds                      13979 non-null  int64
#  4   baths                     13979 non-null  int64
#  5   address                   13979 non-null  object
#  6   furnishing                13979 non-null  object
#  7   completion_status         13979 non-null  object
#  8   post_date                 13979 non-null  object
#  9   average_rent              13979 non-null  int64
#  10  building_name             13979 non-null  object
#  11  year_of_completion        13979 non-null  int64
#  12  total_parking_spaces      13979 non-null  int64
#  13  total_floors              13979 non-null  int64
#  14  total_building_area_sqft  13979 non-null  int64
#  15  elevators                 13979 non-null  int64
#  16  area_name                 13979 non-null  object
#  17  city                      13979 non-null  object
#  18  country                   13979 non-null  object
#  19  Latitude                  13979 non-null  float64
#  20  Longitude                 13979 non-null  float64
#  21  purpose                   13979 non-null  object
# dtypes: float64(2), int64(9), object(11)
# memory usage: 2.5+ MB

# %%
#Define Outliers
# Specify the columns you want to plot
columns_to_plot = ['price', 'beds', 'baths', 'total_building_area_sqft', 'total_floors']

# Create subplots for the boxplots
fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(15, 10))

# Iterate over the columns and plot the boxplots
for i, col in enumerate(columns_to_plot):
    sns.boxplot(y=UAE_Real_Estate[col], ax=axes[i])
    axes[i].set_title(col)

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
UAE_RealState.columns
# Out:
# Index(['price', 'price_category', 'type', 'beds', 'baths', 'address',
#        'furnishing', 'completion_status', 'post_date', 'average_rent',
#        'building_name', 'year_of_completion', 'total_parking_spaces',
#        'total_floors', 'total_building_area_sqft', 'elevators', 'area_name',
#        'city', 'country', 'Latitude', 'Longitude', 'purpose'],
#       dtype='object')

# %%
UAE_Real_Estate.columns
# Out:
# Index(['price', 'price_category', 'type', 'beds', 'baths', 'address',
#        'furnishing', 'completion_status', 'post_date', 'average_rent',
#        'building_name', 'year_of_completion', 'total_parking_spaces',
#        'total_floors', 'total_building_area_sqft', 'elevators', 'area_name',
#        'city', 'country', 'Latitude', 'Longitude', 'purpose'],
#       dtype='object')

# %%
type_counts=UAE_Real_Estate['type'].value_counts()
type_counts
# Out:
# type
# Apartment               22851
# Villa                    4940
# Townhouse                2337
# Residential Plot          573
# Penthouse                 274
# Hotel Apartment           155
# Residential Building       75
# Villa Compound             25
# Residential Floor           5
# Name: count, dtype: int64

# %%
# Plot the pie chart with only colors
plt.figure(figsize=(12,8))
# Calculate percentages
percentages = type_counts / type_counts.sum() * 100

# Create pie (no labels or autopct)
patches,text = plt.pie(type_counts, colors=plt.cm.tab20.colors, startangle=90)

# Add legend with both label + %
labels_with_pct = [f"{label} ({p:.1f}%)" for label, p in zip(type_counts.index, percentages)]
plt.legend(patches, labels_with_pct, loc="center left", bbox_to_anchor=(1, 0.5))

plt.show()

# %%
furnishing_counts=UAE_Real_Estate['furnishing'].value_counts()
furnishing_counts
# Out:
# furnishing
# Unfurnished    23879
# Furnished       7356
# Name: count, dtype: int64

# %%
plt.pie(furnishing_counts,startangle=90,autopct='%.0f%%',labels=furnishing_counts.index)
plt.title('Furnishing Status of Properties in UAE')
plt.show()

# %%
completion_status_counts =UAE_Real_Estate['completion_status'].value_counts()
completion_status_counts
# Out:
# completion_status
# Ready       18710
# Off-Plan    12525
# Name: count, dtype: int64

# %%
plt.pie(completion_status_counts, labels=completion_status_counts.index, autopct='%1.0f%%')
plt.title('Property Completion Status in UAE')
plt.show()

# %%
UAE_Real_Estate
# Out:
#          price price_category       type  beds  baths  \
# 0      1450000         Medium  Apartment     1      2
# 1      6600000           High  Townhouse     5      5
# 2      4825000           High  Apartment     2      3
# 3       980000        Average  Apartment     3      3
# 4      2499999         Medium  Townhouse     3      4
# ...        ...            ...        ...   ...    ...
# 41376  7100000           High  Apartment     2      2
# 41377   928200        Average  Apartment     0      1
# 41378  3188900           High  Apartment     2      2
# 41379   670000        Average  Apartment     0      1
# 41380   650000        Average  Apartment     0      1
#
#                                                  address   furnishing  \
# 0                           The Bay, Business Bay, Dubai    Furnished
# 1                         Brookfield, DAMAC Hills, Dubai  Unfurnished
# 2         Vida Residence Downtown, Downtown Dubai, Dubai  Unfurnished
# 3      Building 39, Al Reef Downtown, Al Reef, Abu Dhabi  Unfurnished
# 4                                Nima, The Valley, Dubai    Furnished
# ...                                                  ...          ...
# 41376  Serenia Living Tower 1, Serenia Living, Palm J...  Unfurnished
# 41377  Upper House East, Upper House, Jumeirah Lake T...  Unfurnished
# 41378  Jadeel Building 3, Jadeel, Madinat Jumeirah Li...  Unfurnished
# 41379  Luxor by Imtiaz, JVC District 14, Jumeirah Vil...  Unfurnished
# 41380  LOCI Residences, JVC District 14, Jumeirah Vil...  Unfurnished
#
#       completion_status   post_date  average_rent  ... total_parking_spaces  \
# 0                 Ready  2024-04-15             0  ...                    0
# 1                 Ready  2024-04-15             0  ...                    0
# 2                 Ready  2024-04-18        288929  ...                  510
# 3                 Ready  2024-01-03         73384  ...                    0
# 4              Off-Plan  2024-02-28             0  ...                    0
# ...                 ...         ...           ...  ...                  ...
# 41376          Off-Plan  2024-02-13             0  ...                  625
# 41377          Off-Plan  2024-02-13             0  ...                  401
# 41378          Off-Plan  2024-02-09             0  ...                    0
# 41379          Off-Plan  2024-03-05             0  ...                    0
# 41380          Off-Plan  2024-01-30             0  ...                  111
#
#        total_floors  total_building_area_sqft  elevators  \
# 0                 0                         0          0
# 1                 0                         0          0
# 2                56                         1         11
# 3                 0                         0          0
# 4                 0                         0          0
# ...             ...                       ...        ...
# 41376            19                       384          6
# 41377            40                       890          7
# 41378             0                         0          0
# 41379             0                         0          0
# 41380             8                       168          2
#
#                            area_name       city country   Latitude  Longitude  \
# 0                       Business Bay      Dubai     UAE  25.189427  55.264819
# 1                        DAMAC Hills      Dubai     UAE  25.028148  55.264246
# 2                     Downtown Dubai      Dubai     UAE  25.186684  55.274705
# 3                            Al Reef  Abu Dhabi     UAE  24.466437  54.656891
# 4                         The Valley      Dubai     UAE  25.019221  55.447201
# ...                              ...        ...     ...        ...        ...
# 41376                  Palm Jumeirah      Dubai     UAE  25.118088  55.134201
# 41377     Jumeirah Lake Towers (JLT)      Dubai     UAE  25.069063  55.141166
# 41378                     Umm Suqeim      Dubai     UAE  25.164759  55.218728
# 41379  Jumeirah Village Circle (JVC)      Dubai     UAE  25.055945  55.207465
# 41380  Jumeirah Village Circle (JVC)      Dubai     UAE  25.055945  55.207465
#
#         purpose
# 0      For Sale
# 1      For Sale
# 2      For Sale
# 3      For Sale
# 4      For Sale
# ...         ...
# 41376  For Sale
# 41377  For Sale
# 41378  For Sale
# 41379  For Sale
# 41380  For Sale
#
# [31235 rows x 22 columns]

# %%
UAE_Real_Estate['price'] = (
    UAE_Real_Estate['price']
    .replace('[,]', '', regex=True)   # remove commas
    .astype(float)                    # convert to float
)

# %%
price_category_counts = UAE_Real_Estate["price_category"].value_counts()
price_category_counts
# Out:
# price_category
# High       10551
# Average    10419
# Medium     10265
# Name: count, dtype: int64

# %%
plt.pie(price_category_counts, labels=price_category_counts.index, autopct='%1.0f%%')
plt.title('Distribution of Prices in UAE Real Estate')
plt.show()

# %%
combined_df = pd.concat([df_UAE, UAE_Real_Estate], ignore_index=True, sort=False)

# %%
combined_df.shape
# Out:
# (33825, 32)

# %%
combined_df.describe()
# Out:
#        building_total_floors  apartment_floor  apartment_rooms          beds  \
# count            2590.000000      2590.000000      2590.000000  33825.000000
# mean               10.722394         3.780695         2.227027      2.057443
# std                18.720891        10.762858         1.625942      1.553898
# min                 0.000000         0.000000        -1.000000      0.000000
# 25%                 0.000000         0.000000         1.000000      1.000000
# 50%                 0.000000         0.000000         2.000000      2.000000
# 75%                14.000000         0.000000         3.000000      3.000000
# max               124.000000       202.000000        10.000000     11.000000
#
#               baths     price_USD         year         price  average_rent  \
# count  33825.000000  2.590000e+03  2590.000000  3.123500e+04  3.123500e+04
# mean       2.775137  1.288600e+06   989.563707  3.941360e+06  9.411035e+04
# std        1.788366  2.560016e+06   985.179635  8.830454e+06  2.699008e+05
# min        0.000000  0.000000e+00     0.000000  0.000000e+00  0.000000e+00
# 25%        1.000000  2.951375e+05     0.000000  1.100000e+06  0.000000e+00
# 50%        2.000000  5.127140e+05  1970.000000  2.000000e+06  0.000000e+00
# 75%        4.000000  9.302205e+05  1970.000000  3.693325e+06  1.243045e+05
# max       11.000000  2.913102e+07  1970.000000  4.825000e+08  2.807952e+07
#
#        total_parking_spaces  total_floors  total_building_area_sqft  \
# count          31235.000000  31235.000000              31235.000000
# mean             174.141636     13.408100                148.538082
# std              349.950416     20.202632                250.375265
# min                0.000000      0.000000                  0.000000
# 25%                0.000000      0.000000                  0.000000
# 50%                0.000000      0.000000                  0.000000
# 75%              215.000000     22.000000                226.000000
# max             2929.000000     89.000000                997.000000
#
#           elevators      Latitude     Longitude
# count  31235.000000  31217.000000  31217.000000
# mean       2.353258     25.035569     55.154647
# std        4.456912      0.418951      0.491043
# min        0.000000     15.175847     43.351928
# 25%        0.000000     25.027951     55.135252
# 50%        0.000000     25.078641     55.239298
# 75%        4.000000     25.189427     55.290669
# max       42.000000     25.797689     56.361294

# %%
df_UAE.columns
# Out:
# Index(['title', 'country', 'address', 'year_of_completion',
#        'building_total_floors', 'apartment_floor', 'apartment_rooms', 'beds',
#        'baths', 'area_sqm', 'apartment_living_area', 'price_USD', 'image',
#        'url', 'year'],
#       dtype='object')

# %%
combined_df.columns
# Out:
# Index(['title', 'country', 'address', 'year_of_completion',
#        'building_total_floors', 'apartment_floor', 'apartment_rooms', 'beds',
#        'baths', 'area_sqm', 'apartment_living_area', 'price_USD', 'image',
#        'url', 'year', 'price', 'price_category', 'type', 'furnishing',
#        'completion_status', 'post_date', 'average_rent', 'building_name',
#        'total_parking_spaces', 'total_floors', 'total_building_area_sqft',
#        'elevators', 'area_name', 'city', 'Latitude', 'Longitude', 'purpose'],
#       dtype='object')

# %%
UAE_Real_Estate.columns
# Out:
# Index(['price', 'price_category', 'type', 'beds', 'baths', 'address',
#        'furnishing', 'completion_status', 'post_date', 'average_rent',
#        'building_name', 'year_of_completion', 'total_parking_spaces',
#        'total_floors', 'total_building_area_sqft', 'elevators', 'area_name',
#        'city', 'country', 'Latitude', 'Longitude', 'purpose'],
#       dtype='object')

# %%
combined_df['price_AED'] = combined_df['price']

# %%
combined_df['price_in_USD'] = combined_df['price_USD'].fillna(combined_df['price_AED'] * 0.2723)

# %% [markdown]
# ## 3. Average price by city?

# %%
uae_cities = ['Dubai', 'Abu Dhabi', 'Sharjah', 'Ajman', 'Ras Al Khaimah']
combined_df = combined_df[combined_df['city'].isin(uae_cities)]

# %%
combined_df_average=combined_df.groupby('city')['price_in_USD'].median().sort_values(ascending=False)
combined_df_average
# Out:
# city
# Dubai             599060.00
# Abu Dhabi         571802.77
# Ras Al Khaimah    530985.00
# Sharjah           432957.00
# Ajman             195102.95
# Name: price_in_USD, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=combined_df_average.values,
            y=combined_df_average.index,
            hue=combined_df_average.index,
            palette='dark:blue',
            legend=False)
plt.title('UAE Median Property Price by City', fontsize=16, pad=20)
plt.xlabel('Median Price USD')
plt.ylabel('City')

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:.0f}k'))

sns.despine()
plt.tight_layout()
plt.show()

# %%
#area_sqft means total area measured in square feet (sqft = square feet).
